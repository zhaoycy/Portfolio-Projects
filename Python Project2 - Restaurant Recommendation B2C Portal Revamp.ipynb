# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('data.xlsx')
df.head(30)
# Out:
#     Restaurant ID                             Restaurant Name  Country Code  \
# 0         7402935                                        Skye            94
# 1         7410290                    Satoo - Hotel Shangri-La            94
# 2         7420899                                  Sushi Masa            94
# 3         7421967                              3 Wise Monkeys            94
# 4         7422489                 Avec Moi Restaurant and Bar            94
# 5        18352452                  Lucky Cat Coffee & Kitchen            94
# 6        18386856                                     Onokabe            94
# 7         7423482                                  Lemongrass            94
# 8        18391256                                       MONKS            94
# 9         7422633                            Talaga Sampireun            94
# 10       18425821                                        OJJU            94
# ...

# %%
df_cleaned['Restaurant Name'].value_counts().index
# Out:
# Index([                      'Cafe Coffee Day',
#                               'Domino's Pizza',
#                                       'Subway',
#                             'Green Chick Chop',
#                                   'McDonald's',
#                                    'Keventers',
#                                    'Pizza Hut',
#                                        'Giani',
#                               'Baskin Robbins',
#                              'Barbeque Nation',
#        ...
#                                   'La-Cuisine',
#                          'Spicy Punjabi Tadka',
#                          'Hurry Curry Express',
#                         'The Big Buddha Grill',
#                             'Mishti's Kitchen',
#                         'The Chickmunks CafÌ©',
#                               'Punjabi Chaska',
#        'Amrit's Agni Multi Cuisine Restaurant',
#                                  'Quick Grabs',
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         1
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df['Cuisines'].fillna(df['Cuisines'].mode()[0],inplace=True)
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         1
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.shape
# Out:
# (9551, 19)

# %%
df_cleaned = df.dropna(subset=['Restaurant Name'])
df_cleaned.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df_cleaned.shape
# Out:
# (9550, 19)

# %%
df_cleaned.duplicated().sum()
# Out:
# 0

# %%
ax = sns.countplot(x='City',order=df_cleaned['City'].value_counts().index,data=df_cleaned)

# %%
df_cleaned['City'].value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad', 'Guwahati',
#        'Amritsar', 'Lucknow', 'Bhubaneshwar', 'Pocatello',
#        ...
#        'Montville', 'Palm Cove', 'Tanunda', 'Chatham-Kent', 'Consort',
#        'Lincoln', 'Monroe', 'Potrero', 'Weirton', 'Miller'],
#       dtype='object', name='City', length=141)

# %%
ax = sns.countplot(x='City', data=df_cleaned, order=list(df_cleaned['City'].value_counts().index[:3]) + list(df_cleaned['City'].value_counts().index[-3:]))
ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 10),
                textcoords = 'offset points')

# %%
sns.countplot(x='Rating text',data=df_cleaned)
# Out:
# <Axes: xlabel='Rating text', ylabel='count'>

# %%
vc=df_cleaned['Has Table booking'].value_counts()
vc
# Out:
# Has Table booking
# No     8392
# Yes    1158
# Name: count, dtype: int64

# %%
8392/1158
# Out:
# 7.246977547495682

# %%
vc=df_cleaned['Has Table booking'].value_counts(normalize=True) * 100
vc
# Out:
# Has Table booking
# No     87.874346
# Yes    12.125654
# Name: proportion, dtype: float64

# %%
sns.boxplot(x='Has Online delivery',y='Votes',data=df_cleaned)
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='Votes'>

# %%
top_cuisines = df['Cuisines'].value_counts().head(10).index
filtered_df = df[df['Cuisines'].isin(top_cuisines)]
sns.barplot(x='City',y='Cuisines',data=df_cleaned)
# Out:
# <Axes: xlabel='City', ylabel='Cuisines'>

# %%
df_cleaned['Cuisine_Count'] = df_cleaned['Cuisines'].apply(lambda x: len(x.split(',')))

# %%
df_cleaned['Cuisine_Count'] .max()
# Out:
# 8

# %%
df_cleaned['Cuisine_Count'] .min()
# Out:
# 1

# %%
sns.boxplot(x=df_cleaned['Rating text'],y=df_cleaned['Cuisine_Count'] )
# Out:
# <Axes: xlabel='Rating text', ylabel='Cuisine_Count'>

# %%
sns.scatterplot(x='Average Cost for two',y='Cuisine_Count',data=df_cleaned)
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='Cuisine_Count'>

# %%
sns.scatterplot(x='Average Cost for two',y='Aggregate rating',data=df_cleaned)
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='Aggregate rating'>

# %%
sns.boxplot(x=df_cleaned['Has Online delivery'],y=df_cleaned['Aggregate rating'] )
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='Aggregate rating'>
